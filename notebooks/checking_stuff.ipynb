# %%
cd /app
# Out:
# /app

# %%
from cybulde.data_processing.dataset_cleaners import SpellCorrectionDatasetCleaner
from cybulde.utils.utils import SpellCorrectionModel
# Out:
# /app/cybulde/utils/utils.py:6: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
spell_correction_model = SpellCorrectionModel()
cleaner = SpellCorrectionDatasetCleaner(spell_correction_model)

# %%
text = "whereis th elove hehad dated forImuch of tepast who couqdn'tread in sixthgrade and ins pired him"

# %%
cleaner(text)
# Out:
# "where is the love he had dated for much of repast who couldn't read in sixth grade and inspired him"
